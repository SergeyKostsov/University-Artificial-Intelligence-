# %% [markdown]
# 1. Загрузите данные и разделите на слова.
# 2. Создайте словарь и превратите данные в индексы.
# 3. Превратите данные в обучающую выборку.
# 4. Напишите нейронные сети.
#
# Четыре нейронки, которые нужно написать:
# 1. Embedding + Dense сеть.
# 2. Embedding + LSTM сеть.
# 3. Embedding + Conv1D сеть.
# 4. Embedding + сложная сеть из Dense, LSTM и Conv1D.

# %% [markdown]
# RNN и CNN в обработке текстов (Университет искусственного интеллекта) Ultra Light`

# %%
from google.colab import files #модуль для загрузки файлов в colab
import numpy as np #библиотека для работы с массивами данных
import pandas as pd #библиотека для обработки и анализа данных
import matplotlib.pyplot as plt #библиотека для визуализации данных
# "Магическая"команда python для запуска библиотеки в ноутбуке
# %matplotlib inline

from tensorflow.keras import utils #модуль с утилитами кераса, будем использовать для вызова метода преобразования категорий в вектора
from tensorflow.keras.models import Sequential #последовательная модель нейросети кераса
# Загружаем стандартные слои нейросети(полносвязный, регуляризации, нормализации, векторного представления слов, выравнивания, активации)
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Embedding, Flatten, Activation
# Загружаем сверточные слои
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D
# Загружаем рекуррентные слои
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Bidirectional
# Загружаем алгоритмы обучения/оптимизации
from tensorflow.keras.optimizers import Adam, RMSprop

from keras.preprocessing.text import Tokenizer, text_to_word_sequence #инструменты предобработки текста от кераса
from sklearn.model_selection import train_test_split #модуль для разбиения данных на обучающую и тестовую выборки
from tensorflow.keras.utils import plot_model
import seaborn as sns
sns.set_style('darkgrid')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Чтение файла в текст
def readText(fileName):  # функция принимает имя файла
  f = open(fileName, 'r')   # открываем файл в режиме чтения
  text = f.read()
  text = text.replace("\n", " ") # переносы строки преобразуем в пробелы

  return text       # возврат преобразованного текста из функции

# Загрузка обучающих текстов
trainText = []
trainText.append(readText('/content/drive/MyDrive/Базы/Тексты писателей/(Булгаков) Обучающая_5 вместе (1).txt'))
trainText.append(readText('/content/drive/MyDrive/Базы/Тексты писателей/(Стругацкие) Обучающая_5 вместе (1).txt'))
trainText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Булгаков) Обучающая_5 вместе (1).txt'))
trainText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Клиффорд_Саймак) Обучающая_5 вместе (1).txt'))
trainText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Макс Фрай) Обучающая_5 вместе (1).txt'))
trainText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Рэй Брэдберри) Обучающая_22 вместе (1).txt')) 

className = ["О. Генри", "Стругацкие", "Булгаков", "Саймак", "Фрай", "Брэдбери"]
nClasses = len(className)

# Загрузка тестовых текстов
testText = []
testText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(О. Генри) Тестовая_20 вместе (1).txt'))
testText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Стругацкие) Тестовая_2 вместе (1).txt'))
testText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Булгаков) Тестовая_2 вместе (1).txt'))
testText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Клиффорд_Саймак) Тестовая_2 вместе (1).txt'))
testText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Макс Фрай) Тестовая_2 вместе (1).txt'))
testText.append(readText('/content/drive/My Drive/Базы/Тексты писателей/(Рэй Брэдберри) Тестовая_8 вместе (1).txt'))

# %% [markdown]
# ОБРАБОТКА ДАННЫХ

# %%
# Преобразование текстовых данных в числовые/векторные для обучения нейросети

maxWordsCount = 20000 # определяем максимальное количество слов/индексов, учитываемое при обучении текстов

# встроенной в Keras функцией Tokenizer разбиваем текст и превращаем в матрицу числовых значений
tokenizer = Tokenizer(num_words=maxWordsCount, filters='–—!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n\xa0–\ufeff', lower=True, split=' ', char_level=False, oov_token='unknown')
# (char_level=False) - просим токенайзер не удалять однобуквенные слова, индексация по словам а не по символам
tokenizer.fit_on_texts(trainText) # передача методу собирающему словарь частотности
items = list(tokenizer.word_index.items()) # извлекаем индексы слов для просмотра

# %%
print(items[:100])
# Out:
# [('unknown', 1), ('и', 2), ('в', 3), ('не', 4), ('я', 5), ('что', 6), ('на', 7), ('с', 8), ('а', 9), ('он', 10), ('как', 11), ('то', 12), ('это', 13), ('но', 14), ('у', 15), ('все', 16), ('по', 17), ('его', 18), ('к', 19), ('так', 20), ('из', 21), ('за', 22), ('мне', 23), ('меня', 24), ('ты', 25), ('же', 26), ('бы', 27), ('было', 28), ('сказал', 29), ('вы', 30), ('от', 31), ('они', 32), ('только', 33), ('мы', 34), ('да', 35), ('еще', 36), ('о', 37), ('она', 38), ('вот', 39), ('был', 40), ('уже', 41), ('когда', 42), ('если', 43), ('ни', 44), ('нет', 45), ('их', 46), ('ну', 47), ('до', 48), ('чтобы', 49), ('для', 50), ('ему', 51), ('ничего', 52), ('очень', 53), ('может', 54), ('даже', 55), ('или', 56), ('кто', 57), ('там', 58), ('тут', 59), ('ее', 60), ('под', 61), ('потом', 62), ('него', 63), ('просто', 64), ('чем', 65), ('быть', 66), ('где', 67), ('время', 68), ('во', 69), ('теперь', 70), ('есть', 71), ('нас', 72), ('со', 73), ('тебя', 74), ('ли', 75), ('тебе', 76), ('раз', 77), ('вас', 78), ('сейчас', 79), ('этот', 80), ('том', 81), ('себя', 82), ('нибудь', 83), ('этого', 84), ('уж', 85), ('надо', 86), ('вам', 87), ('себе', 88), ('будет', 89), ('сам', 90), ('того', 91), ('здесь', 92), ('можно', 93), ('были', 94), ('была', 95), ('»', 96), ('нам', 97), ('один', 98), ('тоже', 99), ('без', 100)]

# %%
print('Протестируем словарь частотности')
print('Интересующее слово имеет индекс: ', tokenizer.word_index[input('Уточните слово')])
# Out:
# Протестируем словарь частотности
# Уточните словоперсик
# Интересующее слово имеет индекс:  80606

# %%
# преобразуем текст в последовательность индексов согласно частотному словарю
trainWordIndexes = tokenizer.texts_to_sequences(trainText)
testWordIndexes = tokenizer.texts_to_sequences(testText)

print('Взглянем на последовательность обучающего текста:')
print('В виде оригинального текста: ', trainText[1][:87])
print('Он же в виде последовательности индексов: ', trainWordIndexes[1][:20])

print() # для чего?
print()

print('Статистика по обучающим текстам: ')
for i in range(6):
  print(className[i], " ", len(trainText[i]), 'символов,', len(trainWordIndexes[i]), 'слов')
print('В сумме ', len(trainText[0])+len(trainText[1])+len(trainText[2])+len(trainText[3])+len(trainText[4])+len(trainText[5]), 'символов', len(trainWordIndexes[0])+len(trainWordIndexes[1])+len(trainWordIndexes[2])+len(trainWordIndexes[3])+len(trainWordIndexes[4])+len(trainWordIndexes[5]), 'слов')
print()
print('Статистика по обучающим текстам: ')
for i in range(6):
  print(className[i], ' ', len(testText[i]), 'символов ', len(testWordIndexes[i]), 'слов')
print('В сумме ', len(testText[0])+len(testText[1])+len(testText[2])+len(testText[3])+len(testText[4])+len(testText[5]), 'символов, ', len(testWordIndexes[0])+len(testWordIndexes[1])+len(testWordIndexes[2])+len(testWordIndexes[3])+len(testWordIndexes[4])+len(testWordIndexes[5]), 'слов')
# Out:
# Взглянем на последовательность обучающего текста:
# В виде оригинального текста:  Парень из преисподней     1     Ну и деревня! Сроду я таких деревень не видел и не знал
# Он же в виде последовательности индексов:  [507, 21, 1, 963, 47, 2, 11062, 8830, 5, 442, 1, 4, 275, 2, 4, 274, 55, 6, 241, 9027]
#
#
# Статистика по обучающим текстам:
# О. Генри   1765648 символов, 262109 слов
# Стругацкие   2042469 символов, 313405 слов
# Булгаков   1765648 символов, 262109 слов
# Саймак   1609507 символов, 251551 слов
# Фрай   3700010 символов, 569052 слов
# Брэдбери   1386454 символов, 214694 слов
# В сумме  12269736 символов 1872920 слов
#
# Статистика по обучающим текстам:
# О. Генри   349662 символов  53255 слов
# Стругацкие   704846 символов  108730 слов
# Булгаков   875042 символов  132910 слов
# Саймак   318811 символов  50362 слов
# Фрай   1278191 символов  196911 слов
# Брэдбери   868673 символов  132746 слов
# В сумме  4395225 символов,  674914 слов

# %% [markdown]
# СОЗДАНИЕ ОБУЧАЮЩЕЙ И ТЕСТОВОЙ ВЫБОРКИ

# %% [markdown]
# Функции для формирования выборки  по отрезкам с заданным шагом

# %%
# Формирование обучающей выборки по листу индексов слов (разделение на короткие векторы)
def getSetFromIndexes(wordIndexes, xLen, step):
  xSample = []
  wordsLen = len(wordIndexes)
  index = 0 # Разделение на векторы длины xLen и смещение вперед на шаг step

  while (index + xLen <=wordsLen):
    xSample.append(wordIndexes[index:index+xLen])
    index += step

  return xSample

# %%
# Формирование обучающей и проверочной выборок из двух листов индексов от двух классов

def createSetsMultiClasses(wordIndexes, xLen, step): # функция принимает последовательность индексов, размер окна, шаг окна 
  # для каждого из 6 классов создам обучающую/проверочную выборку из классов
  nClasses = len(wordIndexes) # задаем количество классов выборки
  classesXSamples = [] # здесь будет список размером "количество классов * количество окон в тексте * длину окна(например 6 по 1341*1000"
  for wI in wordIndexes:   #для каждого текста выборки из последовательности индексов
    classesXSamples.append(getSetFromIndexes(wI, xLen, step))   # добавляем в список очередной текст индексов, разбитый на "количество окон * длину окна"
  
  #Формируем один общий xSamples
  xSamples = [] # здесь будет список размером "суммарное кол-во окон во всех текстах * длину окна" (например 1341*1000)
  ySamples = [] # здесь будет список размером "суммарное кол-во окон во всех текстах * вектор длиной 6"

  for t in range(nClasses): # в диапазоне количества классов(6)
    xT = classesXSamples[t] # берем очередной текст вида "кол-во окон в тексте * длину окна" (например 1341*1000)
    for i in range(len(xT)):  # и каждое его окно
      xSamples.append(xT[i])  # добавляем в общий список выборки

    # Формируем ySamples по номеру класса
    currY = utils.to_categorical(t, nClasses) # текущий класс переводится в вектор длиной 6 вида [0.0.0.1.0.0.]
    for i in range(len(xT)): # на каждое окно выборки
      ySamples.append(currY) # добавляем соответствующий вектор класса

  xSamples = np.array(xSamples)
  ySamples = np.array(ySamples) # переводим в numpy для подачи в нейронку

  return (xSamples, ySamples) # функция возвращает выборку и соответствующие векторы классов

# %% [markdown]
# ПОДГОТОВКА ДАННЫХ

# %%
# Задаем базовые параметры
xLen = 1000 # длина отрезка текста, по которой анализируем, в словах
step = 100 # шаг разбития исходного текста на обучающие вектора

# %%
# Формируем обучающую и тестовую выборку
xTrain, yTrain = createSetsMultiClasses(trainWordIndexes, xLen, step) # извлекаем обучающую выборку
xTest, yTest = createSetsMultiClasses(trainWordIndexes, xLen, step) # извлекаем тестовую выборку
print(xTrain.shape)
print(yTrain.shape)
print(xTest.shape)
print(yTest.shape)
# получили обучающий/тестовый набор, достаточный для запуска Embedding, но для Bag of Words нужно xTrain и xTest представить в виде векторов из 0 и 1
# Out:
# (18673, 1000)
# (18673, 6)
# (18673, 1000)
# (18673, 6)

# %% [markdown]
# Распознавание проверочной выборки

# %%
# Представляем тестовую выборку в удобных для распознавания размерах
def createTestMultiClasses(wordIndexes, xLen, step): # функция принимает последовательность индексов, размер окна, шаг окна

  # Для каждого из 6 классов
  # Создаём тестовую выборку из индексов
  nClasses = len(wordIndexes) # задаем количество классов
  xTest6Classes01 = []               # здесь будет список из всех классов,каждый размером "кол-во окон в тексте * 20000(при maxWordsCount=20000)"
  xTest6Classes = []                 # здесь будет список массивов, каждый размером "кол-во окон в тексте * длину окна"(6 по 420*1000)
  for wI in wordIndexes:             # для каждого тестового текста из последовательности индексов
    sample = (getSetFromIndexes(wI, xLen, step)) # тестовая выборка размером "кол-во окон*длину окна"(например 420*1000)
    xTest6Classes.append(np.array(sample))       # переводим в массив numpy и добавляем в список
    xTest6Classes01.append(tokenizer.sequences_to_matrix(sample)) # трансформируется в Bag of Words в виде "кол-во окон в тексте * 20000"
  xTest6Classes01 = np.array(xTest6Classes01)                     # и добавляется к нашему списку, 
  
  return xTest6Classes01, xTest6Classes # функция вернёт тестовые данные: TestBg 6 классов на n*20000 и xTestEm 6 по n*1000



# Расспознаём тестовую выборку и выводим результаты


def recognizeMultiClass(model, xTest, modelName):
  print("НЕЙРОНКА: ", modelName)
  print()
  
  val = []
  pred = []
  
  totalSumRec = []
  
  # Проходим по всем классам
  for i in range(nClasses):
    # Получаем результаты распознавания класса по блокам слов длины xLen
    currPred = model.predict(xTest[i])
    pred.append(currPred)
    # Определяем номер распознанного класса для каждохо блока слов длины xLen
    currOut = np.argmax(currPred, axis=1)
    
    # Считаем процент распознавания каждого класса за каждый
    # Получам матрицу 6 на 6
    evVal = []
    sumRec = []
    for j in range(nClasses):
      sumRec.append(0)
      for t in range(len(currOut)):
        if (currOut[t] == j):
          sumRec[j] += 1
      evVal.append(sumRec[j] / len(currOut))
    
    totalSumRec.append(sumRec[i])
    
    # Определяем, какой в класс в итоге за какой был распознан
    val.append(evVal[i])
    recognizedClass = np.argmax(evVal)
    
    # Выводим результаты распознавания по текущему классу
    isRecognized = "распознано НЕ ВЕРНО!"
    if (recognizedClass == i):
      isRecognized = "распознано ВЕРНО!"
    print(className[i], " распознано ", int(100*evVal[i]), "% сеть считает, что это ", className[recognizedClass], ", ", isRecognized)
  
  # Выводим вредний процент распознавания по всем классам вместе
  print()
  sumVal = 0
  sumCount = 0
  lenXtest = []
  for i in range(nClasses):
    sumCount += len(xTest[i])
    sumVal += totalSumRec[i]
  print("Средний процент распознавания ", int(100*sumVal/sumCount), "%")
  print()
  return sumVal/sumCount

xTest6Classes01, xTest6Classes = createTestMultiClasses(testWordIndexes, xLen, step) # подгоним форму тестовых классов под функцию recognizeMultiClass
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   del sys.path[0]

# %% [markdown]
# НЕЙРОНКИ

# %% [markdown]
# 1. Embedding + Dense сеть.

# %%
modelED = Sequential()
modelED.add(Embedding(maxWordsCount, 14, input_length=xLen))
modelED.add(BatchNormalization())
modelED.add(Dropout(0.25))
modelED.add(Flatten())
modelED.add(Dense (6, activation="softmax"))

modelED.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

modelED.summary()
print()
plot_model(modelED, dpi=60, show_shapes=True) # Выводим схему модели
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 1000, 14)          280000
#
#  batch_normalization_1 (Batc  (None, 1000, 14)         56
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1000, 14)          0
#
#  flatten_1 (Flatten)         (None, 14000)             0
#
#  dense_1 (Dense)             (None, 6)                 84006
#
# =================================================================
# Total params: 364,062
# Trainable params: 364,034
# Non-trainable params: 28
# _________________________________________________________________

# %%
history = modelED.fit(xTrain,
                      yTrain,
                      epochs=15,
                      batch_size=512,
                      validation_data=(xTest, yTest))
# Out:
# Epoch 1/15
# 37/37 [==============================] - 4s 75ms/step - loss: 1.1404 - accuracy: 0.5473 - val_loss: 1.5551 - val_accuracy: 0.4843
# Epoch 2/15
# 37/37 [==============================] - 1s 38ms/step - loss: 0.3590 - accuracy: 0.8004 - val_loss: 1.3941 - val_accuracy: 0.3161
# Epoch 3/15
# 37/37 [==============================] - 1s 36ms/step - loss: 0.3295 - accuracy: 0.8028 - val_loss: 1.3078 - val_accuracy: 0.3157
# Epoch 4/15
# 37/37 [==============================] - 1s 36ms/step - loss: 0.3144 - accuracy: 0.7993 - val_loss: 1.2376 - val_accuracy: 0.3264
# Epoch 5/15
# 37/37 [==============================] - 1s 38ms/step - loss: 0.2939 - accuracy: 0.7972 - val_loss: 1.1542 - val_accuracy: 0.3814
# Epoch 6/15
# 37/37 [==============================] - 2s 46ms/step - loss: 0.2782 - accuracy: 0.8009 - val_loss: 1.0411 - val_accuracy: 0.5345
# Epoch 7/15
# 37/37 [==============================] - 1s 37ms/step - loss: 0.2659 - accuracy: 0.7997 - val_loss: 0.9701 - val_accuracy: 0.6615
# Epoch 8/15
# 37/37 [==============================] - 1s 39ms/step - loss: 0.2557 - accuracy: 0.7961 - val_loss: 1.0844 - val_accuracy: 0.7145
# Epoch 9/15
# 37/37 [==============================] - 1s 38ms/step - loss: 0.2456 - accuracy: 0.7965 - val_loss: 0.6564 - val_accuracy: 0.7199
# Epoch 10/15
# 37/37 [==============================] - 1s 39ms/step - loss: 0.2381 - accuracy: 0.7961 - val_loss: 0.4476 - val_accuracy: 0.7348
# Epoch 11/15
# 37/37 [==============================] - 1s 37ms/step - loss: 0.2304 - accuracy: 0.7919 - val_loss: 0.2803 - val_accuracy: 0.8514
# Epoch 12/15
# 37/37 [==============================] - 1s 37ms/step - loss: 0.2265 - accuracy: 0.7946 - val_loss: 0.2121 - val_accuracy: 0.8601
# Epoch 13/15
# 37/37 [==============================] - 1s 39ms/step - loss: 0.2217 - accuracy: 0.7968 - val_loss: 0.1955 - val_accuracy: 0.8601
# Epoch 14/15
# 37/37 [==============================] - 1s 36ms/step - loss: 0.2179 - accuracy: 0.7950 - val_loss: 0.1956 - val_accuracy: 0.8601
# Epoch 15/15
# 37/37 [==============================] - 1s 32ms/step - loss: 0.2147 - accuracy: 0.7989 - val_loss: 0.1948 - val_accuracy: 0.8601

# %%
# Строим график отображения динамики ошибки работы модели
plt.figure(figsize = (14,7))
plt.plot(history.history['loss'],
         label='Значение ошибки на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Значение ошибки на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Значение ошибки')
plt.legend()
plt.show()

# График отображения динамики обучения и точности предсказания сети
plt.figure(figsize = (14,7))
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %%
pred=recognizeMultiClass(modelED, xTest6Classes, 'ED') # функция покажет, какие классы и как распознаны верно
# Out:
# НЕЙРОНКА:  ED
#
# О. Генри  распознано  5 % сеть считает, что это  Саймак ,  распознано НЕ ВЕРНО!
# Стругацкие  распознано  18 % сеть считает, что это  Фрай ,  распознано НЕ ВЕРНО!
# Булгаков  распознано  36 % сеть считает, что это  Булгаков ,  распознано ВЕРНО!
# Саймак  распознано  58 % сеть считает, что это  Саймак ,  распознано ВЕРНО!
# Фрай  распознано  85 % сеть считает, что это  Фрай ,  распознано ВЕРНО!
# Брэдбери  распознано  69 % сеть считает, что это  Брэдбери ,  распознано ВЕРНО!
#
# Средний процент распознавания  53 %

# %% [markdown]
# 2. Embedding + LSTM сеть.

# %%
modelELS = Sequential()
modelELS.add(Embedding(maxWordsCount, 14, input_length=xLen))
modelELS.add(SpatialDropout1D(0.25))  # слой регуляризации, "выключающий" 1D карты объектов из Embedding векторов, во избежание переобучения
modelELS.add(BatchNormalization())
modelELS.add(LSTM(6))
modelELS.add(Dense (6, activation="softmax"))

modelELS.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

modelELS.summary()
print()
plot_model(modelELS, dpi=70) # Выводим схему модели
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 1000, 14)          280000
#
#  spatial_dropout1d (SpatialD  (None, 1000, 14)         0
#  ropout1D)
#
#  batch_normalization_2 (Batc  (None, 1000, 14)         56
#  hNormalization)
#
#  lstm (LSTM)                 (None, 6)                 504
#
#  dense_2 (Dense)             (None, 6)                 42
#
# =================================================================
# Total params: 280,602
# Trainable params: 280,574
# Non-trainable params: 28
# _________________________________________________________________

# %%
history = modelELS.fit(xTrain,
                      yTrain,
                      epochs=20,
                      batch_size=512,
                      validation_data=(xTest, yTest))
# Out:
# Epoch 1/20
# 37/37 [==============================] - 12s 207ms/step - loss: 1.7512 - accuracy: 0.2665 - val_loss: 1.7500 - val_accuracy: 0.3042
# Epoch 2/20
# 37/37 [==============================] - 6s 173ms/step - loss: 1.6428 - accuracy: 0.3605 - val_loss: 1.7111 - val_accuracy: 0.3042
# Epoch 3/20
# 37/37 [==============================] - 7s 195ms/step - loss: 1.5273 - accuracy: 0.4159 - val_loss: 1.5495 - val_accuracy: 0.4456
# Epoch 4/20
# 37/37 [==============================] - 6s 171ms/step - loss: 1.3709 - accuracy: 0.4844 - val_loss: 1.8513 - val_accuracy: 0.1453
# Epoch 5/20
# 37/37 [==============================] - 6s 167ms/step - loss: 1.2176 - accuracy: 0.5470 - val_loss: 1.9389 - val_accuracy: 0.1425
# Epoch 6/20
# 37/37 [==============================] - 6s 164ms/step - loss: 1.0977 - accuracy: 0.6129 - val_loss: 1.9950 - val_accuracy: 0.1536
# Epoch 7/20
# 37/37 [==============================] - 6s 163ms/step - loss: 0.9847 - accuracy: 0.6734 - val_loss: 2.0703 - val_accuracy: 0.2578
# Epoch 8/20
# 37/37 [==============================] - 6s 164ms/step - loss: 0.9030 - accuracy: 0.7158 - val_loss: 2.0251 - val_accuracy: 0.2669
# Epoch 9/20
# 37/37 [==============================] - 6s 163ms/step - loss: 0.8194 - accuracy: 0.7452 - val_loss: 1.9092 - val_accuracy: 0.3317
# Epoch 10/20
# 37/37 [==============================] - 6s 161ms/step - loss: 0.7545 - accuracy: 0.7643 - val_loss: 1.7030 - val_accuracy: 0.4441
# Epoch 11/20
# 37/37 [==============================] - 6s 162ms/step - loss: 0.6989 - accuracy: 0.7805 - val_loss: 1.3261 - val_accuracy: 0.5971
# Epoch 12/20
# 37/37 [==============================] - 6s 162ms/step - loss: 0.6636 - accuracy: 0.7817 - val_loss: 1.3794 - val_accuracy: 0.5816
# Epoch 13/20
# 37/37 [==============================] - 6s 161ms/step - loss: 0.6119 - accuracy: 0.7972 - val_loss: 1.3351 - val_accuracy: 0.5934
# Epoch 14/20
# 37/37 [==============================] - 6s 162ms/step - loss: 0.5718 - accuracy: 0.8039 - val_loss: 0.9964 - val_accuracy: 0.6935
# Epoch 15/20
# 37/37 [==============================] - 6s 162ms/step - loss: 0.5242 - accuracy: 0.8128 - val_loss: 0.6933 - val_accuracy: 0.7775
# Epoch 16/20
# 37/37 [==============================] - 6s 164ms/step - loss: 0.4882 - accuracy: 0.8171 - val_loss: 0.5340 - val_accuracy: 0.8127
# Epoch 17/20
# 37/37 [==============================] - 6s 162ms/step - loss: 0.4714 - accuracy: 0.8196 - val_loss: 0.4674 - val_accuracy: 0.8218
# Epoch 18/20
# 37/37 [==============================] - 7s 190ms/step - loss: 0.4367 - accuracy: 0.8216 - val_loss: 0.3938 - val_accuracy: 0.8389
# Epoch 19/20
# 37/37 [==============================] - 6s 169ms/step - loss: 0.4053 - accuracy: 0.8318 - val_loss: 0.3517 - val_accuracy: 0.8465
# Epoch 20/20
# 37/37 [==============================] - 6s 170ms/step - loss: 0.3978 - accuracy: 0.8320 - val_loss: 0.3066 - val_accuracy: 0.8552

# %%
# Строим график отображения динамики ошибки работы модели
plt.figure(figsize = (14,7))
plt.plot(history.history['loss'],
         label='Значение ошибки на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Значение ошибки на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Значение ошибки')
plt.legend()
plt.show()

# График отображения динамики обучения и точности предсказания сети
plt.figure(figsize = (14,7))
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %%
pred=recognizeMultiClass(modelELS, xTest6Classes, 'Embedding и LSTM') # функция покажет, какие классы и как распознаны верно
# Out:
# НЕЙРОНКА:  Embedding и LSTM
#
# О. Генри  распознано  1 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Стругацкие  распознано  63 % сеть считает, что это  Стругацкие ,  распознано ВЕРНО!
# Булгаков  распознано  15 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Саймак  распознано  17 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Фрай  распознано  68 % сеть считает, что это  Фрай ,  распознано ВЕРНО!
# Брэдбери  распознано  68 % сеть считает, что это  Брэдбери ,  распознано ВЕРНО!
#
# Средний процент распознавания  48 %

# %% [markdown]
# 3. Embedding + Conv1D сеть.

# %%
modelEC_1 = Sequential()
modelEC_1.add(Embedding(maxWordsCount, 14, input_length=xLen))
modelEC_1.add(SpatialDropout1D(0.25))
modelEC_1.add(BatchNormalization())
modelEC_1.add(Conv1D(20,5, activation='relu', padding='same')) # одномерный сверточный слой с указанием количества фильтров и ширины окна для фильтров
modelEC_1.add(MaxPooling1D(2))
modelEC_1.add(Dropout(0.25))
modelEC_1.add(Flatten())
modelEC_1.add(Dense(6, activation='softmax'))

modelEC_1.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

modelEC_1.summary()
print()
plot_model(modelEC_1, dpi=70, show_shapes=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 1000, 14)          280000
#
#  spatial_dropout1d_2 (Spatia  (None, 1000, 14)         0
#  lDropout1D)
#
#  batch_normalization_3 (Batc  (None, 1000, 14)         56
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 1000, 20)          1420
#
#  max_pooling1d_2 (MaxPooling  (None, 500, 20)          0
#  1D)
#
#  dropout_4 (Dropout)         (None, 500, 20)           0
#
#  flatten_2 (Flatten)         (None, 10000)             0
#
#  dense_3 (Dense)             (None, 6)                 60006
#
# =================================================================
# Total params: 341,482
# Trainable params: 341,454
# Non-trainable params: 28
# _________________________________________________________________

# %%
history = modelEC_1.fit(xTrain,
                      yTrain,
                      epochs=20,
                      batch_size=512,
                      validation_data=(xTest, yTest))
# Out:
# Epoch 1/20
# 37/37 [==============================] - 6s 94ms/step - loss: 3.1986 - accuracy: 0.2330 - val_loss: 1.7826 - val_accuracy: 0.4349
# Epoch 2/20
# 37/37 [==============================] - 2s 56ms/step - loss: 1.3751 - accuracy: 0.5119 - val_loss: 1.7555 - val_accuracy: 0.3134
# Epoch 3/20
# 37/37 [==============================] - 2s 61ms/step - loss: 0.6122 - accuracy: 0.7667 - val_loss: 1.6773 - val_accuracy: 0.3709
# Epoch 4/20
# 37/37 [==============================] - 2s 56ms/step - loss: 0.3235 - accuracy: 0.8502 - val_loss: 1.5774 - val_accuracy: 0.4975
# Epoch 5/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.2587 - accuracy: 0.8485 - val_loss: 1.5617 - val_accuracy: 0.5280
# Epoch 6/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.2367 - accuracy: 0.8416 - val_loss: 1.4991 - val_accuracy: 0.6924
# Epoch 7/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.2162 - accuracy: 0.8480 - val_loss: 1.4053 - val_accuracy: 0.7857
# Epoch 8/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.2121 - accuracy: 0.8373 - val_loss: 1.2494 - val_accuracy: 0.8202
# Epoch 9/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.2064 - accuracy: 0.8418 - val_loss: 1.0645 - val_accuracy: 0.8481
# Epoch 10/20
# 37/37 [==============================] - 2s 62ms/step - loss: 0.2052 - accuracy: 0.8398 - val_loss: 0.8778 - val_accuracy: 0.8582
# Epoch 11/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.2028 - accuracy: 0.8391 - val_loss: 0.6523 - val_accuracy: 0.8592
# Epoch 12/20
# 37/37 [==============================] - 2s 56ms/step - loss: 0.2015 - accuracy: 0.8369 - val_loss: 0.4669 - val_accuracy: 0.8599
# Epoch 13/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.1999 - accuracy: 0.8407 - val_loss: 0.3296 - val_accuracy: 0.8601
# Epoch 14/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.1993 - accuracy: 0.8453 - val_loss: 0.2403 - val_accuracy: 0.8601
# Epoch 15/20
# 37/37 [==============================] - 2s 62ms/step - loss: 0.1983 - accuracy: 0.8384 - val_loss: 0.2105 - val_accuracy: 0.8601
# Epoch 16/20
# 37/37 [==============================] - 2s 56ms/step - loss: 0.1977 - accuracy: 0.8456 - val_loss: 0.2016 - val_accuracy: 0.8601
# Epoch 17/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.1975 - accuracy: 0.8447 - val_loss: 0.1955 - val_accuracy: 0.8601
# Epoch 18/20
# 37/37 [==============================] - 2s 56ms/step - loss: 0.1973 - accuracy: 0.8429 - val_loss: 0.1982 - val_accuracy: 0.8601
# Epoch 19/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.1976 - accuracy: 0.8460 - val_loss: 0.1946 - val_accuracy: 0.8601
# Epoch 20/20
# 37/37 [==============================] - 2s 57ms/step - loss: 0.1970 - accuracy: 0.8443 - val_loss: 0.1947 - val_accuracy: 0.8601

# %%
# Строим график отображения динамики ошибки работы модели
plt.figure(figsize = (14,7))
plt.plot(history.history['loss'],
         label='Значение ошибки на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Значение ошибки на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Значение ошибки')
plt.legend()
plt.show()

# График отображения динамики обучения и точности предсказания сети
plt.figure(figsize = (14,7))
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %%
pred=recognizeMultiClass(modelEC_1, xTest6Classes, 'Embedding и Dense') # функция покажет, какие классы и как распознаны верно
# Out:
# НЕЙРОНКА:  Embedding и Dense
#
# О. Генри  распознано  3 % сеть считает, что это  Фрай ,  распознано НЕ ВЕРНО!
# Стругацкие  распознано  40 % сеть считает, что это  Стругацкие ,  распознано ВЕРНО!
# Булгаков  распознано  45 % сеть считает, что это  Булгаков ,  распознано ВЕРНО!
# Саймак  распознано  42 % сеть считает, что это  Фрай ,  распознано НЕ ВЕРНО!
# Фрай  распознано  86 % сеть считает, что это  Фрай ,  распознано ВЕРНО!
# Брэдбери  распознано  55 % сеть считает, что это  Брэдбери ,  распознано ВЕРНО!
#
# Средний процент распознавания  55 %

# %% [markdown]
# 4. Embedding + сложная сеть из Dense, LSTM и Conv1D.

# %%
modelDLC_1 = Sequential() # создаём последовательную модель нейросети
# преобразовываем каждое слово в многомерный вектор c указанием размерности вектора и длины входных данных
modelDLC_1.add(Embedding(maxWordsCount, 10, input_length=xLen))
modelDLC_1.add(Dense(100, activation='relu'))
modelDLC_1.add(Dropout(0.25))
modelDLC_1.add(SpatialDropout1D(0.2)) # добавляем слой регуляризации, "выключая" 1D карты объектов из эмбединг векторов, во избежание переобучения
modelDLC_1.add(LSTM(14, return_sequences=1)) # добавляем слой LSTM, совместимый с Cuda при поддержке GPU
modelDLC_1.add(Dropout(0.2))
modelDLC_1.add(BatchNormalization())
modelDLC_1.add(Conv1D(20, 5, activation="relu")) # добавляем одномерный сверточный слой, указывая кол-во фильтров и ширину окна для фильтров 
modelDLC_1.add(Conv1D(20, 5, activation="relu")) 
modelDLC_1.add(MaxPooling1D(2)) # добавляем слой подвыборки/пулинга с функцией максимума
modelDLC_1.add(Dropout(0.2)) 
modelDLC_1.add(BatchNormalization()) 
modelDLC_1.add(Flatten())
modelDLC_1.add(Dense(6, activation='softmax'))

# Компиляция, составление модели с выбором алгоритма оптимизации, функции потерь и метрики точности
modelDLC_1.compile(optimizer='rmsprop', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

modelDLC_1.summary()
print()
plot_model(modelDLC_1, dpi=70,  show_shapes=True)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 1000, 10)          200000
#
#  dense_4 (Dense)             (None, 1000, 100)         1100
#
#  dropout_5 (Dropout)         (None, 1000, 100)         0
#
#  spatial_dropout1d_3 (Spatia  (None, 1000, 100)        0
#  lDropout1D)
#
#  lstm_1 (LSTM)               (None, 1000, 14)          6440
#
#  dropout_6 (Dropout)         (None, 1000, 14)          0
#
#  batch_normalization_4 (Batc  (None, 1000, 14)         56
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 996, 20)           1420
#
#  conv1d_5 (Conv1D)           (None, 992, 20)           2020
#
#  max_pooling1d_3 (MaxPooling  (None, 496, 20)          0
#  1D)
#
#  dropout_7 (Dropout)         (None, 496, 20)           0
#
#  batch_normalization_5 (Batc  (None, 496, 20)          80
#  hNormalization)
#
#  flatten_3 (Flatten)         (None, 9920)              0
#
#  dense_5 (Dense)             (None, 6)                 59526
#
# =================================================================
# Total params: 270,642
# Trainable params: 270,574
# Non-trainable params: 68
# _________________________________________________________________

# %%
history = modelDLC_1.fit(xTrain,
                      yTrain,
                      epochs=20,
                      batch_size=512,
                      validation_data=(xTest, yTest))
# Out:
# Epoch 1/20
# 37/37 [==============================] - 16s 333ms/step - loss: 1.7515 - accuracy: 0.3550 - val_loss: 1.9052 - val_accuracy: 0.1674
# Epoch 2/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.6556 - accuracy: 0.7011 - val_loss: 2.1125 - val_accuracy: 0.1342
# Epoch 3/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.2979 - accuracy: 0.8392 - val_loss: 2.2269 - val_accuracy: 0.1342
# Epoch 4/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.2446 - accuracy: 0.8451 - val_loss: 2.3341 - val_accuracy: 0.1342
# Epoch 5/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.2222 - accuracy: 0.8517 - val_loss: 2.0498 - val_accuracy: 0.3042
# Epoch 6/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.2180 - accuracy: 0.8479 - val_loss: 2.2839 - val_accuracy: 0.3042
# Epoch 7/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2130 - accuracy: 0.8522 - val_loss: 2.4324 - val_accuracy: 0.3042
# Epoch 8/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.2091 - accuracy: 0.8504 - val_loss: 2.6530 - val_accuracy: 0.3042
# Epoch 9/20
# 37/37 [==============================] - 11s 312ms/step - loss: 0.2071 - accuracy: 0.8511 - val_loss: 2.4342 - val_accuracy: 0.3042
# Epoch 10/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2051 - accuracy: 0.8511 - val_loss: 2.8749 - val_accuracy: 0.3042
# Epoch 11/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2022 - accuracy: 0.8536 - val_loss: 2.6650 - val_accuracy: 0.3057
# Epoch 12/20
# 37/37 [==============================] - 11s 312ms/step - loss: 0.2027 - accuracy: 0.8510 - val_loss: 2.5751 - val_accuracy: 0.1760
# Epoch 13/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.2011 - accuracy: 0.8564 - val_loss: 2.8791 - val_accuracy: 0.4727
# Epoch 14/20
# 37/37 [==============================] - 11s 313ms/step - loss: 0.2002 - accuracy: 0.8535 - val_loss: 1.4834 - val_accuracy: 0.2959
# Epoch 15/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.1991 - accuracy: 0.8558 - val_loss: 2.0414 - val_accuracy: 0.2962
# Epoch 16/20
# 37/37 [==============================] - 11s 312ms/step - loss: 0.1995 - accuracy: 0.8594 - val_loss: 2.1443 - val_accuracy: 0.6138
# Epoch 17/20
# 37/37 [==============================] - 11s 312ms/step - loss: 0.1997 - accuracy: 0.8544 - val_loss: 0.2079 - val_accuracy: 0.8601
# Epoch 18/20
# 37/37 [==============================] - 11s 309ms/step - loss: 0.1980 - accuracy: 0.8594 - val_loss: 3.6319 - val_accuracy: 0.4896
# Epoch 19/20
# 37/37 [==============================] - 11s 311ms/step - loss: 0.1983 - accuracy: 0.8551 - val_loss: 3.6560 - val_accuracy: 0.3421
# Epoch 20/20
# 37/37 [==============================] - 11s 310ms/step - loss: 0.1979 - accuracy: 0.8559 - val_loss: 4.3145 - val_accuracy: 0.5032

# %%
# Строим график отображения динамики ошибки работы модели
plt.figure(figsize = (14,7))
plt.plot(history.history['loss'],
         label='Значение ошибки на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Значение ошибки на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Значение ошибки')
plt.legend()
plt.show()

# График отображения динамики обучения и точности предсказания сети
plt.figure(figsize = (14,7))
plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %%
pred=recognizeMultiClass(modelDLC_1, xTest6Classes, 'Embedding и Dense') # функция покажет, какие классы и как распознаны верно
# Out:
# НЕЙРОНКА:  Embedding и Dense
#
# О. Генри  распознано  0 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Стругацкие  распознано  100 % сеть считает, что это  Стругацкие ,  распознано ВЕРНО!
# Булгаков  распознано  0 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Саймак  распознано  4 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Фрай  распознано  9 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
# Брэдбери  распознано  47 % сеть считает, что это  Стругацкие ,  распознано НЕ ВЕРНО!
#
# Средний процент распознавания  28 %

# %% [markdown]
# Судя по всему, веса очень резко меняют точность, поэтому может выглядеть как переобучение. По данной модели целесообразен возврат к ключам 17 эпохи с точностью 86,01 и последующее дообучение с существенно, раз в 100 уменьшенным значением lr.`
